# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('https://s3.us.cloud-object-storage.appdomain.cloud/cf-courses-data/CognitiveClass/DP0701EN/version-2/Data-Collisions.csv')
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
acc = df[['SEVERITYCODE','ADDRTYPE','WEATHER','ROADCOND','LIGHTCOND','PERSONCOUNT','VEHCOUNT','COLLISIONTYPE','UNDERINFL','HITPARKEDCAR','SPEEDING']]

# %%
df.columns.values
# Out:
# array(['SEVERITYCODE', 'X', 'Y', 'OBJECTID', 'INCKEY', 'COLDETKEY',
#        'REPORTNO', 'STATUS', 'ADDRTYPE', 'INTKEY', 'LOCATION',
#        'EXCEPTRSNCODE', 'EXCEPTRSNDESC', 'SEVERITYCODE.1', 'SEVERITYDESC',
#        'COLLISIONTYPE', 'PERSONCOUNT', 'PEDCOUNT', 'PEDCYLCOUNT',
#        'VEHCOUNT', 'INCDATE', 'INCDTTM', 'JUNCTIONTYPE', 'SDOT_COLCODE',
#        'SDOT_COLDESC', 'INATTENTIONIND', 'UNDERINFL', 'WEATHER',
#        'ROADCOND', 'LIGHTCOND', 'PEDROWNOTGRNT', 'SDOTCOLNUM', 'SPEEDING',
#        'ST_COLCODE', 'ST_COLDESC', 'SEGLANEKEY', 'CROSSWALKKEY',
#        'HITPARKEDCAR'], dtype=object)

# %%
df.groupby('HITPARKEDCAR').mean()
# Out:
#               SEVERITYCODE           X          Y       OBJECTID  \
# HITPARKEDCAR
# N                 1.308017 -122.330421  47.619681  105646.879914
# Y                 1.062084 -122.333044  47.615945  182061.563331
#
#                      INCKEY      COLDETKEY        INTKEY  SEVERITYCODE.1  \
# HITPARKEDCAR
# N             136761.515067  136950.420427  37532.032792        1.308017
# Y             253574.522173  254261.162140  47299.107955        1.062084
#
#               PERSONCOUNT  PEDCOUNT  PEDCYLCOUNT  VEHCOUNT  SDOT_COLCODE  \
# HITPARKEDCAR
# N                2.458361  0.038510     0.029383  1.914732     13.995988
# Y                2.082456  0.001524     0.002633  2.077882     10.536863
#
#                 SDOTCOLNUM  SEGLANEKEY  CROSSWALKKEY
# HITPARKEDCAR
# N             7.972502e+06  279.252863  10159.019263
# Y             1.021801e+07   13.472700      0.000000

# %%
acc['SEVERITYCODE'] = acc['SEVERITYCODE'].map({1:0, 2:1})
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
acc.head()
# Out:
#    SEVERITYCODE      ADDRTYPE   WEATHER ROADCOND                LIGHTCOND  \
# 0             1  Intersection  Overcast      Wet                 Daylight
# 1             0         Block   Raining      Wet  Dark - Street Lights On
# 2             0         Block  Overcast      Dry                 Daylight
# 3             0         Block     Clear      Dry                 Daylight
# 4             1  Intersection   Raining      Wet                 Daylight
#
#    PERSONCOUNT  VEHCOUNT COLLISIONTYPE UNDERINFL HITPARKEDCAR SPEEDING
# 0            2         2        Angles         N            N      NaN
# 1            2         2     Sideswipe         0            N      NaN
# 2            4         3    Parked Car         0            N      NaN
# 3            3         3         Other         N            N      NaN
# 4            2         2        Angles         0            N      NaN

# %%
acc = acc.rename(columns = {'SEVERITYCODE':'severe_bool'})

# %%
acc.head()
# Out:
#    severe_bool      ADDRTYPE   WEATHER ROADCOND                LIGHTCOND  \
# 0            1  Intersection  Overcast      Wet                 Daylight
# 1            0         Block   Raining      Wet  Dark - Street Lights On
# 2            0         Block  Overcast      Dry                 Daylight
# 3            0         Block     Clear      Dry                 Daylight
# 4            1  Intersection   Raining      Wet                 Daylight
#
#    PERSONCOUNT  VEHCOUNT COLLISIONTYPE UNDERINFL HITPARKEDCAR SPEEDING
# 0            2         2        Angles         N            N      NaN
# 1            2         2     Sideswipe         0            N      NaN
# 2            4         3    Parked Car         0            N      NaN
# 3            3         3         Other         N            N      NaN
# 4            2         2        Angles         0            N      NaN

# %%
acc.head()
# Out:
#    severe_bool      ADDRTYPE   WEATHER ROADCOND                LIGHTCOND  \
# 0            1  Intersection  Overcast      Wet                 Daylight
# 1            0         Block   Raining      Wet  Dark - Street Lights On
# 2            0         Block  Overcast      Dry                 Daylight
# 3            0         Block     Clear      Dry                 Daylight
# 4            1  Intersection   Raining      Wet                 Daylight
#
#    PERSONCOUNT  VEHCOUNT COLLISIONTYPE UNDERINFL HITPARKEDCAR SPEEDING
# 0            2         2        Angles         N            N      NaN
# 1            2         2     Sideswipe         0            N      NaN
# 2            4         3    Parked Car         0            N      NaN
# 3            3         3         Other         N            N      NaN
# 4            2         2        Angles         0            N      NaN

# %%
acc.head()
# Out:
#    severe_bool      ADDRTYPE   WEATHER ROADCOND                LIGHTCOND  \
# 0            1  Intersection  Overcast      Wet                 Daylight
# 1            0         Block   Raining      Wet  Dark - Street Lights On
# 2            0         Block  Overcast      Dry                 Daylight
# 3            0         Block     Clear      Dry                 Daylight
# 4            1  Intersection   Raining      Wet                 Daylight
#
#    PERSONCOUNT  VEHCOUNT COLLISIONTYPE UNDERINFL HITPARKEDCAR SPEEDING
# 0            2         2        Angles         N            N      NaN
# 1            2         2     Sideswipe         0            N      NaN
# 2            4         3    Parked Car         0            N      NaN
# 3            3         3         Other         N            N      NaN
# 4            2         2        Angles         0            N      NaN

# %%
acc['HITPARKEDCAR']
acc['HITPARKEDCAR'].mask(acc['HITPARKEDCAR'] == 'Y', 1, inplace=True)
acc['HITPARKEDCAR'].mask(acc['HITPARKEDCAR'] == 'N', 0, inplace=True)
acc = acc.rename(columns = {'HITPARKEDCAR':'hit_parked_car'})
acc.head()
# Out:
#    severe_bool      ADDRTYPE   WEATHER ROADCOND                LIGHTCOND  \
# 0            1  Intersection  Overcast      Wet                 Daylight
# 1            0         Block   Raining      Wet  Dark - Street Lights On
# 2            0         Block  Overcast      Dry                 Daylight
# 3            0         Block     Clear      Dry                 Daylight
# 4            1  Intersection   Raining      Wet                 Daylight
#
#    PERSONCOUNT  VEHCOUNT COLLISIONTYPE UNDERINFL hit_parked_car SPEEDING
# 0            2         2        Angles         N              0      NaN
# 1            2         2     Sideswipe         0              0      NaN
# 2            4         3    Parked Car         0              0      NaN
# 3            3         3         Other         N              0      NaN
# 4            2         2        Angles         0              0      NaN

# %%
acc['UNDERINFL'].mask(acc['UNDERINFL'] == 'Y', 1, inplace=True)
acc['UNDERINFL'].mask(acc['UNDERINFL'] == '1', 1, inplace=True)
acc['UNDERINFL'].mask(acc['UNDERINFL'] == 'N', 0, inplace=True)
acc['UNDERINFL'].mask(acc['UNDERINFL'] == '0', 0, inplace=True)
acc = acc.rename(columns = {'UNDERINFL':'is_dui'})
acc.head()
# Out:
#    severe_bool      ADDRTYPE   WEATHER ROADCOND                LIGHTCOND  \
# 0            1  Intersection  Overcast      Wet                 Daylight
# 1            0         Block   Raining      Wet  Dark - Street Lights On
# 2            0         Block  Overcast      Dry                 Daylight
# 3            0         Block     Clear      Dry                 Daylight
# 4            1  Intersection   Raining      Wet                 Daylight
#
#    PERSONCOUNT  VEHCOUNT COLLISIONTYPE is_dui hit_parked_car SPEEDING
# 0            2         2        Angles      0              0      NaN
# 1            2         2     Sideswipe      0              0      NaN
# 2            4         3    Parked Car      0              0      NaN
# 3            3         3         Other      0              0      NaN
# 4            2         2        Angles      0              0      NaN

# %%
acc['SPEEDING'].mask(acc['SPEEDING'] == 'Y', 1, inplace=True)
acc = acc.rename(columns = {'SPEEDING':'is_speeding'})
acc['is_speeding'] = acc['is_speeding'].fillna(0)
acc.head()
# Out:
#    severe_bool      ADDRTYPE   WEATHER ROADCOND                LIGHTCOND  \
# 0            1  Intersection  Overcast      Wet                 Daylight
# 1            0         Block   Raining      Wet  Dark - Street Lights On
# 2            0         Block  Overcast      Dry                 Daylight
# 3            0         Block     Clear      Dry                 Daylight
# 4            1  Intersection   Raining      Wet                 Daylight
#
#    PERSONCOUNT  VEHCOUNT COLLISIONTYPE is_dui hit_parked_car  is_speeding
# 0            2         2        Angles      0              0            0
# 1            2         2     Sideswipe      0              0            0
# 2            4         3    Parked Car      0              0            0
# 3            3         3         Other      0              0            0
# 4            2         2        Angles      0              0            0

# %%
cat_vars = ['ADDRTYPE','LIGHTCOND','ROADCOND','WEATHER','COLLISIONTYPE']

for var in cat_vars:
    
    cat_list='var'+'_'+var
    cat_list = pd.get_dummies(acc[var], prefix=var)
    acc1=acc.join(cat_list)
    acc = acc1

# %%
acc.columns.values
# Out:
# array(['severe_bool', 'ADDRTYPE', 'WEATHER', 'ROADCOND', 'LIGHTCOND',
#        'PERSONCOUNT', 'VEHCOUNT', 'COLLISIONTYPE', 'is_dui',
#        'hit_parked_car', 'is_speeding', 'ADDRTYPE_Alley',
#        'ADDRTYPE_Block', 'ADDRTYPE_Intersection',
#        'LIGHTCOND_Dark - No Street Lights',
#        'LIGHTCOND_Dark - Street Lights Off',
#        'LIGHTCOND_Dark - Street Lights On',
#        'LIGHTCOND_Dark - Unknown Lighting', 'LIGHTCOND_Dawn',
#        'LIGHTCOND_Daylight', 'LIGHTCOND_Dusk', 'LIGHTCOND_Other',
#        'LIGHTCOND_Unknown', 'ROADCOND_Dry', 'ROADCOND_Ice',
#        'ROADCOND_Oil', 'ROADCOND_Other', 'ROADCOND_Sand/Mud/Dirt',
#        'ROADCOND_Snow/Slush', 'ROADCOND_Standing Water',
#        'ROADCOND_Unknown', 'ROADCOND_Wet', 'WEATHER_Blowing Sand/Dirt',
#        'WEATHER_Clear', 'WEATHER_Fog/Smog/Smoke', 'WEATHER_Other',
#        'WEATHER_Overcast', 'WEATHER_Partly Cloudy', 'WEATHER_Raining',
#        'WEATHER_Severe Crosswind', 'WEATHER_Sleet/Hail/Freezing Rain',
# ...

# %%
for var in cat_vars:
    acc.drop(var, axis=1, inplace=True)
acc.head()
# Out:
#    severe_bool  PERSONCOUNT  VEHCOUNT is_dui hit_parked_car  is_speeding  \
# 0            1            2         2      0              0            0
# 1            0            2         2      0              0            0
# 2            0            4         3      0              0            0
# 3            0            3         3      0              0            0
# 4            1            2         2      0              0            0
#
#    ADDRTYPE_Alley  ADDRTYPE_Block  ADDRTYPE_Intersection  \
# 0               0               0                      1
# 1               0               1                      0
# 2               0               1                      0
# 3               0               1                      0
# 4               0               0                      1
#
#    LIGHTCOND_Dark - No Street Lights  ...  COLLISIONTYPE_Angles  \
# 0                                  0  ...                     1
# ...

# %%
acc.columns = acc.columns.str.replace('-', '')
acc.columns = acc.columns.str.replace(' ', '_')
acc.columns = acc.columns.str.replace('/', '')
acc.columns = acc.columns.str.replace('__', '_')
acc.columns = map(str.lower, acc.columns)
predictors = list(acc.columns.values)

# %%
predictors.pop(0)
# Out:
# 'severe_bool'

# %%
acc['is_dui'] = acc['is_dui'].fillna(0)

# %%
import statsmodels.api as sm
model = sm.GLM.from_formula("severe_bool ~ personcount + vehcount + is_dui + hit_parked_car + is_speeding + addrtype_alley + addrtype_block + addrtype_intersection + lightcond_dark_no_street_lights + lightcond_dark_street_lights_off + lightcond_dark_street_lights_on + lightcond_dark_unknown_lighting + lightcond_dawn + lightcond_daylight + lightcond_dusk + lightcond_other + lightcond_unknown + roadcond_dry + roadcond_ice + roadcond_oil + roadcond_other + roadcond_sandmuddirt + roadcond_snowslush + roadcond_standing_water + roadcond_unknown + roadcond_wet + weather_blowing_sanddirt + weather_clear + weather_fogsmogsmoke + weather_other + weather_overcast + weather_partly_cloudy + weather_raining + weather_severe_crosswind + weather_sleethailfreezing_rain + weather_snowing + weather_unknown + collisiontype_angles + collisiontype_cycles + collisiontype_head_on + collisiontype_left_turn + collisiontype_other + collisiontype_parked_car + collisiontype_pedestrian + collisiontype_rear_ended + collisiontype_right_turn + collisiontype_sideswipe", family = sm.families.Binomial(), data=acc)
result = model.fit()
result.summary2()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                         Results: Generalized linear model
# ...
# Model:                   GLM                   AIC:                 187713.0151
# Link Function:           logit                 BIC:                 -2182735.7500
# Dependent Variable:      severe_bool           Log-Likelihood:      -93809.
# Date:                    2020-08-19 14:31      LL-Null:             -1.1874e+05
# No. Observations:        194673                Deviance:            1.8762e+05
# Df Model:                47                    Pearson chi2:        1.89e+05
# Df Residuals:            194625                Scale:               1.0000
# Method:                  IRLS
# ---------------------------------------------------------------------------------
#                                   Coef.  Std.Err.    z     P>|z|   [0.025  0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
predictors = ['hit_parked_car','personcount','vehcount', 'is_dui','is_speeding','addrtype_alley','addrtype_block','addrtype_intersection',
             'roadcond_oil','roadcond_sandmuddirt','collisiontype_cycles','collisiontype_parked_car','collisiontype_pedestrian','collisiontype_right_turn',
             'collisiontype_sideswipe']

# %%
predictors
# Out:
# ['hit_parked_car',
#  'personcount',
#  'vehcount',
#  'is_dui',
#  'is_speeding',
#  'addrtype_alley',
#  'addrtype_block',
#  'addrtype_intersection',
#  'roadcond_oil',
#  'roadcond_sandmuddirt',
#  'collisiontype_cycles',
#  'collisiontype_parked_car',
#  'collisiontype_pedestrian',
#  'collisiontype_right_turn',
#  'collisiontype_sideswipe']

# %%
import statsmodels.formula.api as smf

model = smf.logit("severe_bool ~ hit_parked_car +personcount + is_dui +is_speeding +addrtype_alley +addrtype_block +addrtype_intersection + roadcond_oil +roadcond_sandmuddirt +collisiontype_cycles +collisiontype_parked_car +collisiontype_pedestrian +collisiontype_right_turn + collisiontype_sideswipe", data = acc)
result = model.fit()
result.summary2()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.490652
#          Iterations 7
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                              Results: Logit
# ...
# Model:                 Logit              Pseudo R-squared:   0.196
# Dependent Variable:    severe_bool        AIC:                191063.3742
# Date:                  2020-08-19 15:26   BIC:                191216.0603
# No. Observations:      194673             Log-Likelihood:     -95517.
# Df Model:              14                 LL-Null:            -1.1874e+05
# Df Residuals:          194658             LLR p-value:        0.0000
# Converged:             1.0000             Scale:              1.0000
# No. Iterations:        7.0000
# -------------------------------------------------------------------------
#                           Coef.  Std.Err.    z     P>|z|   [0.025  0.975]
# -------------------------------------------------------------------------
# ...

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:            severe_bool   No. Observations:               194673
# Model:                            GLM   Df Residuals:                   194658
# Model Family:                Binomial   Df Model:                           14
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -95517.
# Date:                Wed, 19 Aug 2020   Deviance:                   1.9103e+05
# Time:                        14:31:15   Pearson chi2:                 7.44e+05
# No. Iterations:                     6   Covariance Type:             nonrobust
# ...
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# ...

# %%
X = acc[predictors]
y = acc['severe_bool']

# %%
#Split training sets
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=0)

# %%
# import the class
from sklearn.linear_model import LogisticRegression

# instantiate the model (using the default parameters)
logreg = LogisticRegression(max_iter=10000)


# fit the model with data
logreg.fit(X_train,y_train)

#
y_pred=logreg.predict(X_test)

# %%
from sklearn import metrics
cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
cnf_matrix
# Out:
# array([[32663,  1418],
#        [10477,  4111]])

# %%
# import required modules
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

class_names=[0,1] # name  of classes
fig, ax = plt.subplots(figsize=(10,6))
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)

# create heatmap
ax = sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual severity')
plt.xlabel('Predicted severity')
# Out:
# Text(0.5, 33.0, 'Predicted severity')

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("Precision:",metrics.precision_score(y_test, y_pred))
print("Recall:",metrics.recall_score(y_test, y_pred))
# Out:
# Accuracy: 0.7555939098810331
# Precision: 0.7435340929643697
# Recall: 0.2818069646284618

# %%
y_pred_proba = logreg.predict_proba(X_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)
auc = metrics.roc_auc_score(y_test, y_pred_proba)
plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
plt.legend(loc=4)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-e91b9e5b0069> in <module>
#       3 auc = metrics.roc_auc_score(y_test, y_pred_proba)
#       4 plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
# ----> 5 plt.figsize(10,10)
#       6 plt.legend(loc=4)
#       7 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'figsize'

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(y_test, logreg.predict(X_test))
fpr, tpr, thresholds = roc_curve(y_test, logreg.predict_proba(X_test)[:,1])
plt.figure(figsize=(10,10))
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate',fontsize=14)
plt.ylabel('True Positive Rate',fontsize=14)
plt.title('Receiver operating characteristic (ROC) curve', fontsize=16)
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.96      0.85     34081
#            1       0.74      0.28      0.41     14588
#
#     accuracy                           0.76     48669
#    macro avg       0.75      0.62      0.63     48669
# weighted avg       0.75      0.76      0.71     48669

# %%
acc1 = df[['SEVERITYCODE','ADDRTYPE','WEATHER','ROADCOND','LIGHTCOND','PERSONCOUNT','VEHCOUNT','COLLISIONTYPE','UNDERINFL','HITPARKEDCAR','SPEEDING']]

# %%
acc.head()
# Out:
#    severe_bool  personcount  vehcount  is_dui hit_parked_car  is_speeding  \
# 0            1            2         2       0              0            0
# 1            0            2         2       0              0            0
# 2            0            4         3       0              0            0
# 3            0            3         3       0              0            0
# 4            1            2         2       0              0            0
#
#    addrtype_alley  addrtype_block  addrtype_intersection  \
# 0               0               0                      1
# 1               0               1                      0
# 2               0               1                      0
# 3               0               1                      0
# 4               0               0                      1
#
#    lightcond_dark_no_street_lights  ...  collisiontype_angles  \
# 0                                0  ...                     1
# ...

# %%
acc1.groupby('LIGHTCOND').mean()
# Out:
#                           SEVERITYCODE  PERSONCOUNT  VEHCOUNT
# LIGHTCOND
# Dark - No Street Lights       1.217306     2.214053  1.891997
# Dark - Street Lights Off      1.263553     2.346122  1.919099
# Dark - Street Lights On       1.298411     2.484363  1.936504
# Dark - Unknown Lighting       1.363636     1.818182  1.454545
# Dawn                          1.329337     2.210631  1.892486
# Daylight                      1.331884     2.504456  1.986473
# Dusk                          1.329380     2.527448  1.966960
# Other                         1.221277     2.106383  1.893617
# Unknown                       1.044905     2.040080  1.982632

# %%
c = pd.crosstab(acc['is_dui'], acc['severe_bool'])
c
# Out:
# severe_bool       0      1
# is_dui
# 0            130926  54626
# 1              5559   3562

# %%
acc['is_dui'].unique()
# Out:
# array([0, 1])

# %%
import statsmodels.api as sm
table = sm.stats.Table2x2(np.array(c))
table.summary(method='normal')
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
d = pd.crosstab(acc['is_speeding'], acc['severe_bool'])
import statsmodels.api as sm
table = sm.stats.Table2x2(np.array(d))
table.summary(method='normal')
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
import statsmodels.api as sm
table = sm.stats.Table2x2(np.array(c))
table.summary(method='normal')
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
acc.columns.values
# Out:
# array(['severe_bool', 'personcount', 'vehcount', 'is_dui',
#        'hit_parked_car', 'is_speeding', 'addrtype_alley',
#        'addrtype_block', 'addrtype_intersection',
#        'lightcond_dark_no_street_lights',
#        'lightcond_dark_street_lights_off',
#        'lightcond_dark_street_lights_on',
#        'lightcond_dark_unknown_lighting', 'lightcond_dawn',
#        'lightcond_daylight', 'lightcond_dusk', 'lightcond_other',
#        'lightcond_unknown', 'roadcond_dry', 'roadcond_ice',
#        'roadcond_oil', 'roadcond_other', 'roadcond_sandmuddirt',
#        'roadcond_snowslush', 'roadcond_standing_water',
#        'roadcond_unknown', 'roadcond_wet', 'weather_blowing_sanddirt',
#        'weather_clear', 'weather_fogsmogsmoke', 'weather_other',
#        'weather_overcast', 'weather_partly_cloudy', 'weather_raining',
#        'weather_severe_crosswind', 'weather_sleethailfreezing_rain',
#        'weather_snowing', 'weather_unknown', 'collisiontype_angles',
# ...

# %%
X_test.head()
# Out:
#       hit_parked_car  personcount  vehcount  is_dui  is_speeding  \
# 84956              0            5         2       0            0
# 62977              0            3         1       0            0
# 36442              0            2         2       0            0
# 45504              0            4         2       0            0
# 10919              0            2         1       0            0
#
#        addrtype_alley  addrtype_block  addrtype_intersection  roadcond_oil  \
# 84956               0               0                      1             0
# 62977               0               0                      1             0
# 36442               0               1                      0             0
# 45504               0               0                      1             0
# 10919               0               0                      1             0
#
#        roadcond_sandmuddirt  collisiontype_cycles  collisiontype_parked_car  \
# ...

# %%
y_pred = logreg.predict(X_test)
print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(logreg.score(X_test, y_test)))
# Out:
# Accuracy of logistic regression classifier on test set: 0.76

# %%
print(metrics.mean_absolute_error(y_test, y_pred))
print(metrics.mean_squared_error(y_test, y_pred))
print(np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# 0.2444060901189669
# 0.2444060901189669
# 0.49437444322999435

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:            severe_bool   No. Observations:               194673
# Model:                            GLM   Df Residuals:                   194658
# Model Family:                Binomial   Df Model:                           14
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -95517.
# Date:                Wed, 19 Aug 2020   Deviance:                   1.9103e+05
# Time:                        15:18:21   Pearson chi2:                 7.44e+05
# No. Iterations:                     6   Covariance Type:             nonrobust
# ...
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# ...

# %%
result_odds = pd.DataFrame(np.exp(result.params), columns= ['OR'])
result_odds['z-value']= result.pvalues
result_odds[['2.5%', '97.5%']] = np.exp(result.conf_int())

result_odds
# Out:
#                                  OR        z-value       2.5%      97.5%
# Intercept                  0.162683  1.813166e-108   0.138509   0.191076
# hit_parked_car[T.1]        0.795618   1.891264e-05   0.716482   0.883494
# personcount                1.279422   0.000000e+00   1.268536   1.290402
# is_dui                     1.684449   3.242532e-94   1.602888   1.770159
# is_speeding                1.375667   5.289286e-41   1.313012   1.441312
# addrtype_alley             0.506095   1.896442e-05   0.370413   0.691477
# addrtype_block             1.703737   7.096043e-11   1.451531   1.999765
# addrtype_intersection      2.006791   1.986840e-17   1.708855   2.356671
# roadcond_oil               1.426060   1.875629e-01   0.841187   2.417590
# roadcond_sandmuddirt       1.294969   3.573348e-01   0.746829   2.245421
# collisiontype_cycles      13.775700   0.000000e+00  12.688599  14.955938
# collisiontype_parked_car   0.117833   0.000000e+00   0.112776   0.123117
# ...

# %%
## Plotting multiple plots same figure
fig, (axL, axR) = plt.subplots(2, figsize=(15, 15))
plt.suptitle("Logistic Regression Residual Plots \n using Seaborn Lowess line (N = 400)",fontsize=14)


# Deviance Residuals
sns.regplot(result.fittedvalues, result.resid_dev, ax= axL,
            color="black", scatter_kws={"s": 5},
            line_kws={"color":"b", "alpha":1, "lw":2}, lowess=True)

axL.set_title("Deviance Residuals \n against Fitted Values",fontsize=14)
axL.set_xlabel("Linear Predictor Values",fontsize=12)
axL.set_ylabel("Deviance Residuals",fontsize=12)

# Studentized Pearson Residuals
sns.regplot(result.fittedvalues, result.resid_pearson, ax= axR,
            color="black", scatter_kws={"s": 5},
            line_kws={"color":"r", "alpha":1, "lw":2}, lowess=True)

axR.set_title("Studentized Pearson Residuals \n against Fitted Values",fontsize=14)
axR.set_xlabel("Linear Predictor Values",fontsize=12)
axR.set_ylabel("Studentized Pearson Residuals",fontsize=12)

plt.show()

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194673 entries, 0 to 194672
# Data columns (total 38 columns):
# SEVERITYCODE      194673 non-null int64
# X                 189339 non-null float64
# Y                 189339 non-null float64
# OBJECTID          194673 non-null int64
# INCKEY            194673 non-null int64
# COLDETKEY         194673 non-null int64
# REPORTNO          194673 non-null object
# STATUS            194673 non-null object
# ADDRTYPE          192747 non-null object
# INTKEY            65070 non-null float64
# LOCATION          191996 non-null object
# EXCEPTRSNCODE     84811 non-null object
# EXCEPTRSNDESC     5638 non-null object
# SEVERITYCODE.1    194673 non-null int64
# SEVERITYDESC      194673 non-null object
# COLLISIONTYPE     189769 non-null object
# PERSONCOUNT       194673 non-null int64
# PEDCOUNT          194673 non-null int64
# PEDCYLCOUNT       194673 non-null int64
# VEHCOUNT          194673 non-null int64
# ...
